# %%
import numpy as np
import pandas as pd

# Read
df = pd.read_csv('Data/MPS Stolen Animals Raw.csv')

# Standardise headers
df.columns = (df.columns
              .str.strip()
              .str.lower()
              .str.replace(' ', '_')
              .str.replace('-', '_')
              .str.replace('.', '_'))

display(df.head(3))
# Out:
#    count_of_stolen_animals type_of_animal    borough  \
# 0                      1.0            Dog    Lambeth
# 1                      1.0            Dog  Islington
# 2                      1.0            Dog    Croydon
#
#                type_of_offence animal_recovered year_and_month
# 0           Theft and Handling    Not Recovered       Jan-2010
# 1  Violence Against the Person    Not Recovered       Jan-2010
# 2                      Robbery    Not Recovered       Jan-2010

# %% [markdown]
# #### MISSING DATA

# %%
# Missing data
display(df.isna().sum())
print('\n---\n')
display(round(df.isna().mean() * 100, 2))
# Out:
# count_of_stolen_animals    3
# type_of_animal             1
# borough                    0
# type_of_offence            0
# animal_recovered           0
# year_and_month             0
# dtype: int64
# ---
# count_of_stolen_animals    0.05
# type_of_animal             0.02
# borough                    0.00
# type_of_offence            0.00
# animal_recovered           0.00
# year_and_month             0.00
# dtype: float64

# %% [markdown]
# #### VALUES

# %%
# Standardise string values
str_cols = df.select_dtypes(include=['string']).columns
df[str_cols] = df[str_cols].apply(lambda x: x.str.strip().str.lower())

# View
display(df.head(3))
# Out:
#    count_of_stolen_animals type_of_animal    borough  \
# 0                      1.0            dog    lambeth
# 1                      1.0            dog  islington
# 2                      1.0            dog    croydon
#
#                type_of_offence animal_recovered year_and_month
# 0           theft and handling    not recovered       jan-2010
# 1  violence against the person    not recovered       jan-2010
# 2                      robbery    not recovered       jan-2010

# %% [markdown]
# #### FILTER DATA

# %%
# Filter animal type
df = df[df['type_of_animal'] == 'dog'].copy()

# Reset index
df.reset_index(drop=True, inplace=True)

# View
df['type_of_animal'].value_counts()
# Out:
# type_of_animal
# dog    3747
# Name: count, dtype: int64

# %% [markdown]
# #### DROP COLUMNS

# %%
# Drop columns
df.drop(['count_of_stolen_animals', 'type_of_animal', 'type_of_offence'], axis=1, inplace=True)

# View
display(df.head(3))
# Out:
#      borough animal_recovered year_and_month
# 0    lambeth    not recovered       jan-2010
# 1  islington    not recovered       jan-2010
# 2    croydon    not recovered       jan-2010

# %% [markdown]
# #### WRITE CLEAN DATAFRAME

# %%
# Write
df.to_csv('Data/MPS Stolen Animals Clean.csv', index=False)

# View
display(df.head(3))
# Out:
#      borough animal_recovered year_and_month
# 0    lambeth    not recovered       jan-2010
# 1  islington    not recovered       jan-2010
# 2    croydon    not recovered       jan-2010
